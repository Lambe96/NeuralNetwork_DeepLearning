# %% [markdown]
# ##Required libraries and settings

# %%
# !pip install optuna
# !pip install -U kaleido

# %% [markdown]
# ##Run the study and the training

# %%
# !python NN_REG_OPTUNA_KFOLD.py

# %% [markdown]
# ##Compress the results into a zip file

# %%
# !zip -r study_01_results.zip Study_01_results

# %% [markdown]
# ##Download locally the zip file containing the results

# %%
from google.colab import files
files.download('study_01_results.zip')
